# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_SpotifyFeatures=pd.read_csv("/Users/chiraghasija/Desktop/Projects/Spotify Data Analysis/SpotifyFeatures.csv")
df_SpotifyFeatures.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
#to check null values 

pd.isnull(df_SpotifyFeatures).sum()
# Out:
# genre               0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
df_SpotifyFeatures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232725 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
# ...

# %%
df_SpotifyFeatures.shape
# Out:
# (232725, 18)

# %%
# 15 least popular tracks
sort_df=df_SpotifyFeatures.sort_values("popularity",ascending=True).head(15)
sort_df
# Out:
#                   genre             artist_name  \
# 0                 Movie          Henri Salvador
# 74954  Children's Music             Sing n Play
# 74958  Children's Music  Children Songs Company
# 74959  Children's Music  Children Songs Company
# 74961  Children's Music  Children Songs Company
# 74962  Children's Music  Children Songs Company
# 74963  Children's Music  Children Songs Company
# 74964  Children's Music             Sing n Play
# 56153             Movie         Bruno Pelletier
# 74966  Children's Music  Children Songs Company
# 74967  Children's Music  Children Songs Company
# 74968  Children's Music                   Radha
# 74969  Children's Music  Children Songs Company
# 74970  Children's Music  Children Songs Company
# 74971  Children's Music  Children Songs Company
#
#                                track_name                track_id  popularity  \
# 0             C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV           0
# ...

# %%
# descriptivedf_track.describe().transpose() statistics of Spotify Features and Transpose it

df_SpotifyFeatures.describe().transpose()
# Out:
#                      count           mean            std          min  \
# popularity        232725.0      41.127502      18.189948      0.00000
# acousticness      232725.0       0.368560       0.354768      0.00000
# danceability      232725.0       0.554364       0.185608      0.05690
# duration_ms       232725.0  235122.339306  118935.909299  15387.00000
# energy            232725.0       0.570958       0.263456      0.00002
# instrumentalness  232725.0       0.148301       0.302768      0.00000
# liveness          232725.0       0.215009       0.198273      0.00967
# loudness          232725.0      -9.569885       5.998204    -52.45700
# speechiness       232725.0       0.120765       0.185518      0.02220
# tempo             232725.0     117.666585      30.898907     30.37900
# valence           232725.0       0.454917       0.260065      0.00000
#
#                           25%            50%          75%          max
# ...

# %%
# popular songs

most_popular=df_SpotifyFeatures[df_SpotifyFeatures["popularity"]>90].sort_values(by="popularity",ascending=False)
most_popular[:15]
# Out:
#             genre    artist_name  \
# 107804        Pop  Ariana Grande
# 9027        Dance  Ariana Grande
# 9026        Dance  Ariana Grande
# 86951         Rap    Post Malone
# 107803        Pop    Post Malone
# 107802        Pop  Ariana Grande
# 138918  Reggaeton   Daddy Yankee
# 66643     Hip-Hop   Daddy Yankee
# 107909        Pop   Daddy Yankee
# 86953         Rap    Post Malone
# 92824       Indie         Halsey
# 9037        Dance        Ava Max
# 9028        Dance         Halsey
# 107875        Pop     Pedro Capó
# 107806        Pop    Post Malone
#
#                                            track_name                track_id  \
# 107804                                        7 rings  14msK75pk3pA33pzPVNtBF
# 9027                                          7 rings  14msK75pk3pA33pzPVNtBF
# 9026         break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# 86951                                            Wow.  6MWtB6iiXyIwun0YzU6DFP
# ...

# %%
# To get information at a particular row

df_SpotifyFeatures[["artist_name"]].iloc[26]
# Out:
# artist_name    Henri Salvador
# Name: 26, dtype: object

# %%
# To change milliseconds to seconds

df_SpotifyFeatures["duration"]=df_SpotifyFeatures["duration_ms"].apply(lambda x:round(x/1000))
df_SpotifyFeatures.drop("duration_ms",inplace=True,axis=1)

# %%
df_SpotifyFeatures.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  energy  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389   0.910
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590   0.737
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663   0.131
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240   0.326
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331   0.225
#
#    instrumentalness key  liveness  loudness   mode  speechiness    tempo  \
# ...

# %%
#who has most monthly listeners?

df_SpotifyFeatures["artist_name"].value_counts()
# Out:
# Giuseppe Verdi              1394
# Giacomo Puccini             1137
# Kimbo Children's Music       971
# Nobuo Uematsu                825
# Richard Wagner               804
#                             ...
# Zubin Mehta                    1
# Shawn Lane                     1
# Claudio Arrau                  1
# Charles Daellenbach            1
# Jr Thomas & The Volcanos       1
# Name: artist_name, Length: 14564, dtype: int64

# %%
#artist name whose duration is 238

df_SpotifyFeatures[df_SpotifyFeatures["duration"]==238]["artist_name"]
# Out:
# 206        Adrian Marcel
# 563        Peter Hollens
# 567        Peter Hollens
# 602                 Glad
# 604        Hyannis Sound
#                ...
# 231650    Curtis Harding
# 231653            Panama
# 232222        Jill Scott
# 232577            Bondax
# 232689            Aquilo
# Name: artist_name, Length: 1480, dtype: object

# %%
#heatmap (correlation)
corr_df=df_SpotifyFeatures.drop(["key","mode"],axis=1).corr(method="pearson")
plt.figure(figsize=(15,5))
heatmap=sns.heatmap(corr_df,annot=True,vmin=1,vmax=1,center=0,cmap="inferno")
heatmap.set_title("Correlation heatmap between variable")
heatmap.set_xticklabels(heatmap.get_xticklabels(),rotation=90)
# Out:
# [Text(0.5, 0, 'popularity'),
#  Text(1.5, 0, 'acousticness'),
#  Text(2.5, 0, 'danceability'),
#  Text(3.5, 0, 'energy'),
#  Text(4.5, 0, 'instrumentalness'),
#  Text(5.5, 0, 'liveness'),
#  Text(6.5, 0, 'loudness'),
#  Text(7.5, 0, 'speechiness'),
#  Text(8.5, 0, 'tempo'),
#  Text(9.5, 0, 'valence'),
#  Text(10.5, 0, 'duration')]

# %%
#sample+df = 0.5% of original dataset
sample_df=df_SpotifyFeatures.sample(int(0.005*len(df_SpotifyFeatures)))
sample_df.head()
print(len(sample_df))
# Out:
# 1163

# %%
#Regression plot between loudness and energy

plt.figure(figsize=(10,8))
sns.regplot(data=sample_df,y="loudness",x="energy",color="c").set(title="Loudness vs Energy corr")
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy correlation')]

# %%
# high correlation between loudness and energy

# %%
#regression plot between popularity and acoustiness

plt.figure(figsize=(10,8))
sns.regplot(data=sample_df,y="popularity",x="acousticness",color="c").set(title="popularity vs accoustic correlation")
# Out:
# [Text(0.5, 1.0, 'popularity vs accoustic correlation')]

# %%
# irreveresibly dependent

# %%
plt.title("Duration of song in diff geners")
sns.color_palette("rocket",as_cmap=True)
sns.barplot(y=df_SpotifyFeatures["genre"],x=df_SpotifyFeatures["duration"],data=df_SpotifyFeatures)
plt.xlabel("Duration in milli second")
plt.ylabel("Geners")
# Out:
# Text(0, 0.5, 'Geners')

# %%
df=pd.read_csv("/Users/chiraghasija/Desktop/Projects/Spotify Data Analysis/artists.csv")
df.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
sns.set_style(style="darkgrid")
plt.figure(figsize=(10,5))
famous=df.sort_values("popularity",ascending=False).head(10)
sns.barplot(y="name",x="popularity",data=famous).set(title="Top 10 artists by popularity")
# Out:
# [Text(0.5, 1.0, 'Top 10 artists by popularity')]
